# %% [markdown]
# ### Данный ноутбук является артефактом разработки, то есть служит для анализа данных, проверки гипотез и создание возможных решений

# %%
import pandas as pd

# %%
df_train = pd.read_csv('../data/train.csv')
df_test = pd.read_csv('../data/test.csv')
df = pd.concat([df_train,df_test])
df.shape
# Out:
# (2919, 81)
